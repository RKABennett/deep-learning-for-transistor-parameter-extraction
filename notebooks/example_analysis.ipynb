# %% [markdown]
# # Transistor Parameter Extraction Analysis
#
# This notebook demonstrates how to use the transistor parameter extraction models for analysis and visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os

# Add src to path
sys.path.append("../src")

from transistor_param_extraction import NN_fns, NN_variables

# %% [markdown]
# ## Load Configuration

# %%
import yaml

with open("../configs/default_config.yaml", "r") as f:
    config = yaml.safe_load(f)

print("Configuration loaded:")
print(f"Experiment: {config['experiment']['name']}")
print(f"Version: {config['experiment']['version']}")

# %% [markdown]
# ## Data Analysis

# %%
# Example: Load and visualize some processed data
# This cell would be populated with actual data loading code

print("Data analysis section - add your specific analysis code here")

# %% [markdown]
# ## Model Performance Visualization

# %%
# Example: Visualize model performance metrics
# This would load actual results and create plots

plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.title("Forward Model Performance")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.title("Inverse Model Performance")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.tight_layout()
plt.show()
